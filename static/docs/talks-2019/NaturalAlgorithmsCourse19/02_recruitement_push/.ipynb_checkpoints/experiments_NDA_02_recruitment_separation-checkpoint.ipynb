# %%
import numpy as np

# %%
x = [2*i+1 for i in range(1,101)]

# %%
eps = [0.01*i for i in range(1,11)]

# %%
bias = [2*epsilon for epsilon in eps]

# %%
trials = 1000
result = np.empty([len(eps), len(x)])
for i in range(len(eps)):
    prob = 1/2+eps[i]
    for j in range(len(x)): 
        experiments = np.random.binomial(x[j], prob, trials)
        successes = list(map(lambda y: y>x[j]/2, experiments))
        result[i][j] = sum(successes)

# %%
import matplotlib.pylab as plt

# %%
plt.figure(figsize=(12,6))
for i in range(len(eps)):
    plt.scatter(x, result[i][:], label='$\epsilon=$'+str(eps[i]))
plt.xlabel('Sample size')
plt.ylabel('Probability')
plt.legend()
